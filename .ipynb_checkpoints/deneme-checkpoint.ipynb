# %%
from models import *
from backtest import *
import pandas as pd

data_processor = DataProcessor('AKBNK.E.csv')
#creating df's for linit order book and executions
lob_snaps, execs = data_processor.lob_dfs()
execs.head()
# Out:
#                                      execpx  execqty
# 2022-09-21 10:00:00.091279766+03:00   11.81     5000
# 2022-09-21 10:00:00.106780169+03:00   11.80     1611
# 2022-09-21 10:00:00.119995765+03:00   11.80     1200
# 2022-09-21 10:00:00.121344635+03:00   11.80     8800
# 2022-09-21 10:00:00.125455159+03:00   11.80     1200

# %%
optimizer = StrategyOptimizer(execs, lot_size=1000)
best_params_over_periods = optimizer.walk_forward_optimization(n_train=4, n_test=1)

for params, train_end, test_start in best_params_over_periods:
    print(f"Training ended at trade {train_end}, Testing started from trade {test_start}")
    print(f"Best Parameters: Small Window = {params[0]}, Large Window = {params[1]}, Take Profit Percentage = {params[2]*100}%")
    print("-"*50)
# Out:
# /home/yusuf/Desktop/sampleProj/backtest.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   return np.mean(returns) / np.std(returns)
# /home/yusuf/Desktop/sampleProj/backtest.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   return np.mean(returns) / np.std(returns)
# /home/yusuf/Desktop/sampleProj/backtest.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   return np.mean(returns) / np.std(returns)
# /home/yusuf/Desktop/sampleProj/backtest.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   return np.mean(returns) / np.std(returns)
# /home/yusuf/Desktop/sampleProj/backtest.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   return np.mean(returns) / np.std(returns)
# /home/yusuf/Desktop/sampleProj/backtest.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   return np.mean(returns) / np.std(returns)
# ...
